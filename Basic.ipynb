# %% [markdown]
# <a href="https://colab.research.google.com/github/joygoswaminiloy2023-droid/Basic-Python/blob/main/Basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=0
if num>0:
  print("positive")
elif num==0:
  print("ZERO")
else:
  print("Negative");
# Out:
# ZERO

# %%
num=int(input("Enter a Number"))

if num%2==0:
  print("Even")
else:
  print("odd")
# Out:
# Enter a Number7
# odd

# %%
num_1=int(input("enter num1:"))
num_2=int(input("enter num2:"))
num_3=int(input("enter num3:"))

if num_1>num_2 and num_1>num_3:
  print(num_1,"number 1 is bigger");
elif num_2>num_1 and num_2>num_3:
   print(num_2,"number 2 is bigger");
else:
  print(num_3,"number 3 is bigger");
# Out:
# enter num1:5
# enter num2:3
# enter num3:10
# 10 number 3 is bigger

# %%
print("register Form");
reg_name=input("Enter Your UserName:");
reg_pass=input("Enter password:");
print("register Successfull");

print("Login Form");

log_name=input("login name");
log_pass=input("log_pass");

if reg_name==log_name and reg_pass==log_pass:
  print("login Successfull", log_name)
else:
  print("username or password is incorrect")
# Out:
# register Form
# Enter Your UserName:Joy
# Enter password:Joy123@
# register Successfull
# Login Form
# login nameJoy
# log_passJoy123@
# login Successfull Joy

# %%
fruits=["mango","orange","lichi"]
for fruit in fruits:
  print(fruit)

# %%
# Using a for loop from 1 to 50:

# If a number is divisible by both 3 and 5, print "FizzBuzz".
# If divisible by only 3, print "Fizz".
# If divisible by only 5, print "Buzz".
# Otherwise print the number.


for i in range(1,10):
  if i%3==0 and i%5==0:
    print("Fizzbuzz");
  elif i%3==0:
    print("Fizz");
  elif(i%5==0):
    print("Buzz");
  else:
    print(i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz

# %%
# If B = "asdfghjkl" and the keys a, s, l, and g on the keyboard are damaged (not working), what will be printed when you try to type the string B?

B="asdfghjkl"

for alpha in B:
  if alpha=="a" or alpha=="s" or alpha=="l" or alpha=="g":
    continue
  print(alpha,end="")
# Out:
# dfhjk

# %%
# Array OR List

Food=["Burger","Lemonade","Fuchka"]

print(Food)

#append - add new elenment in the array
Food.append("Ciggarate")
print(Food)

#Insert- i can add new data where i want in the array
Food.insert(1,"Coke")
print(Food)
# Out:
# ['Burger', 'Lemonade', 'Fuchka']
# ['Burger', 'Lemonade', 'Fuchka', 'Ciggarate']
# ['Burger', 'Coke', 'Lemonade', 'Fuchka', 'Ciggarate']

# %%
# len -finding the string and array elements count
name="Joy Goswami Niloy"
len(name)

users=["u1","u2","u3"]
len(users)

# take input by array
users.extend(["u4"])
print(users)

# take input Normally
users.append("u5")
print(users)
# Out:
# ['u1', 'u2', 'u3', 'u4']
# ['u1', 'u2', 'u3', 'u4', 'u5']

# %%
num=[5,4,6,9,8,4,1,2,3]
num.sort()
print(num)


print(sorted(num))

print(sum(num))

num.index(2)

num.pop()
print(num)

num.remove(1)
print(num)
# Out:
# [1, 2, 3, 4, 4, 5, 6, 8, 9]
# [1, 2, 3, 4, 4, 5, 6, 8, 9]
# 42
# [1, 2, 3, 4, 4, 5, 6, 8]
# [2, 3, 4, 4, 5, 6, 8]

# %%
#Most Important Python Concepts for ML

# %%
# indexing
num=[1,2,3,5,7]
print(num[0])
print(num[len(num)-1]) #num[4]
print(num[-5])
# Out:
# 1
# 7
# 1

# %%
# Slicing
num=[1,2,3,5,7]
print(num[:3])
print(num[3:])
print(num[::-1])
# Out:
# [1, 2, 3]
# [5, 7]
# [7, 5, 3, 2, 1]

# %%
#finding Squre
array=[1,2,3]
for data in array:
  print(data*data)

squares=[x*x for x in array]
print(squares)

squares.append(4)
print(squares)
# Out:
# 1
# 4
# 9
# [1, 4, 9]
# [1, 4, 9, 4]

# %%
# enumerate()
pets=["Cat","DOg","Tiger"]
for index,value in enumerate(pets):
  print(index,value)
# Out:
# 0 Cat
# 1 DOg
# 2 Tiger

# %%
# zip()
name=["joy", "nil"]
age=[20,23]

for names,agees in zip(name,age):
  print(agees,names)
# Out:
# 20 joy
# 23 nil
